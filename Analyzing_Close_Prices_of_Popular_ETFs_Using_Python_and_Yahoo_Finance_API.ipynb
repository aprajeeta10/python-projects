# %% [markdown]
# <a href="https://colab.research.google.com/github/aprajeeta10/python-projects/blob/main/Analyzing_Close_Prices_of_Popular_ETFs_Using_Python_and_Yahoo_Finance_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Section 1: Define Tickers and Time Range

# %%
import yfinance as yf
from datetime import datetime, timedelta

# Define the list of tickers
tickers = ['SPY', 'BND', 'GLD', 'QQQ', 'VTI']

# Set the end date to today
end_date = datetime.today()
print(end_date)

# Set the start date to 2 years ago
start_date = end_date - timedelta(days=2 * 365)
print(start_date)
# Out:
# 2024-04-24 05:21:17.774270
# 2022-04-25 05:21:17.774270

# %% [markdown]
# Section 2: Download Close Prices

# %%
import pandas as pd

# Create an empty DataFrame to store the close prices
close_df = pd.DataFrame()

# Download the close prices for each ticker
for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date)
    close_df[ticker] = data['Close']

# Display the DataFrame
print(close_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                    SPY        BND         GLD         QQQ         VTI
# Date
# 2022-04-25  428.510010  76.779999  177.050003  329.579987  215.389999
# 2022-04-26  416.100006  76.980003  177.320007  317.140015  209.250000
# 2022-04-27  417.269989  76.739998  175.979996  316.760010  209.660004
# 2022-04-28  427.809998  76.709999  176.929993  328.010010  214.770004
# 2022-04-29  412.000000  76.190002  176.910004  313.250000  206.880005
# ...                ...        ...         ...         ...         ...
# 2024-04-17  500.549988  70.889999  219.589996  425.839996  247.679993
# 2024-04-18  499.519989  70.699997  220.339996  423.410004  247.169998
# 2024-04-19  495.160004  70.790001  221.029999  414.649994  245.229996
# 2024-04-22  499.720001  70.820000  215.570007  418.820007  247.639999
# 2024-04-23  505.649994  70.949997  215.039993  425.070007  250.589996
#
# [502 rows x 5 columns]

# %% [markdown]
# Section 3: Calculating Returns

# %%
# Calculate daily returns
daily_returns = close_df.pct_change()

# Display the daily returns DataFrame
print(daily_returns)
# Out:
#                  SPY       BND       GLD       QQQ       VTI
# Date
# 2022-04-25       NaN       NaN       NaN       NaN       NaN
# 2022-04-26 -0.028961  0.002605  0.001525 -0.037745 -0.028506
# 2022-04-27  0.002812 -0.003118 -0.007557 -0.001198  0.001959
# 2022-04-28  0.025259 -0.000391  0.005398  0.035516  0.024373
# 2022-04-29 -0.036956 -0.006779 -0.000113 -0.044999 -0.036737
# ...              ...       ...       ...       ...       ...
# 2024-04-17 -0.005918  0.004819 -0.007368 -0.012201 -0.005860
# 2024-04-18 -0.002058 -0.002680  0.003415 -0.005706 -0.002059
# 2024-04-19 -0.008728  0.001273  0.003132 -0.020689 -0.007849
# 2024-04-22  0.009209  0.000424 -0.024702  0.010057  0.009828
# 2024-04-23  0.011867  0.001836 -0.002459  0.014923  0.011912
#
# [502 rows x 5 columns]

# %% [markdown]
# Section 4: Plotting Price Trends

# %%
import matplotlib.pyplot as plt

# Plot the historical close prices
close_df.plot(figsize=(10, 6))
plt.title('Historical Close Prices of Popular ETFs')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Section 5: Developing Trading Strategies

# %%
# Calculate the 50-day simple moving average
sma_50 = close_df.rolling(window=50).mean()

# Calculate the 200-day simple moving average
sma_200 = close_df.rolling(window=200).mean()

# Plot the moving averages along with the historical close prices
close_df.plot(figsize=(10, 6))
sma_50.plot(linestyle='--', linewidth=1)
sma_200.plot(linestyle='--', linewidth=1)
plt.title('Moving Averages and Historical Close Prices of Popular ETFs')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')
plt.show()
